# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
import numpy as np
import pandas as pd
import time, re, random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# first few tagged sentences
print(nltk_data[:10])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
# Splitting into train and validation sets 95:5
random.seed(1234)
train_set, val_set = train_test_split(nltk_data, test_size=0.05, random_state=100)

print(len(train_set))
print(len(val_set))
print(train_set[:10])
# Out:
# 3718
# 196
# [[('One', 'NUM'), ('bright', 'ADJ'), ('sign', 'NOUN'), ('is', 'VERB'), ('that', 'ADP'), ('a', 'DET'), ('growing', 'VERB'), ('number', 'NOUN'), ('of', 'ADP'), ('women', 'NOUN'), ('have', 'VERB'), ('entered', 'VERB'), ('the', 'DET'), ('once', 'ADV'), ('male-dominated', 'ADJ'), ('field', 'NOUN'), (';', '.'), ('more', 'ADJ'), ('than', 'ADP'), ('a', 'DET'), ('third', 'ADJ'), ('of', 'ADP'), ('the', 'DET'), ('ringers', 'NOUN'), ('today', 'NOUN'), ('are', 'VERB'), ('women', 'NOUN'), ('.', '.')], [('``', '.'), ('These', 'DET'), ('days', 'NOUN'), (',', '.'), ('banking', 'NOUN'), ('customers', 'NOUN'), ('walk', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('door', 'NOUN'), ('*-1', 'X'), ('expecting', 'VERB'), ('you', 'PRON'), ('to', 'PRT'), ('have', 'VERB'), ('a', 'DET'), ('package', 'NOUN'), ('especially', 'ADV'), ('for', 'ADP'), ('them', 'PRON'), (',', '.'), ("''", '.'), ('Ms.', 'NOUN'), ('Moore', 'NOUN'), ('says', 'VERB'), ('*T*-2', 'X'), ('.', '.')], [('The', 'DET'), ('rights', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-173', 'X'), ('expire', 'VERB'), ('Nov.', 'NOUN'), ('21', 'NUM'), (',', '.'), ('can', 'VERB'), ('be', 'VERB'), ('exercised', 'VERB'), ('*-104', 'X'), ('for', 'ADP'), ('$', '.'), ('100', 'NUM'), ('*U*', 'X'), ('each', 'DET'), ('.', '.')], [('@', 'ADP')], [('Mr.', 'NOUN'), ('Trudeau', 'NOUN'), ("'s", 'PRT'), ('attorney', 'NOUN'), (',', '.'), ('Norman', 'NOUN'), ('K.', 'NOUN'), ('Samnick', 'NOUN'), (',', '.'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('harassment', 'NOUN'), ('consists', 'VERB'), ('mainly', 'ADV'), ('of', 'ADP'), ('the', 'DET'), ('guild', 'NOUN'), ("'s", 'PRT'), ('year-long', 'ADJ'), ('threats', 'NOUN'), ('of', 'ADP'), ('disciplinary', 'ADJ'), ('action', 'NOUN'), ('.', '.')], [('The', 'DET'), ('ruling', 'NOUN'), ('could', 'VERB'), ('lead', 'VERB'), ('to', 'PRT'), ('the', 'DET'), ('cancellation', 'NOUN'), ('of', 'ADP'), ('huge', 'ADJ'), ('bank', 'NOUN'), ('debts', 'NOUN'), ('0', 'X'), ('the', 'DET'), ('London', 'NOUN'), ('Borough', 'NOUN'), ('of', 'ADP'), ('Hammersmith', 'NOUN'), ('and', 'CONJ'), ('Fulham', 'NOUN'), ('ran', 'VERB'), ('up', 'PRT'), ('*T*-1', 'X'), ('after', 'ADP'), ('*-2', 'X'), ('losing', 'VERB'), ('heavily', 'ADV'), ('on', 'ADP'), ('swap', 'NOUN'), ('transactions', 'NOUN'), ('.', '.')], [("Dunkin'", 'NOUN'), ('has', 'VERB'), ('set', 'VERB'), ('Nov.', 'NOUN'), ('10', 'NUM'), ('as', 'ADP'), ('the', 'DET'), ('deadline', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('receipt', 'NOUN'), ('of', 'ADP'), ('any', 'DET'), ('competing', 'VERB'), ('bids', 'NOUN'), ('.', '.')], [('The', 'DET'), ('sale', 'NOUN'), ('comes', 'VERB'), ('in', 'ADP'), ('place', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('planned', 'VERB'), ('initial', 'ADJ'), ('public', 'ADJ'), ('offering', 'NOUN'), ('of', 'ADP'), ('Lentjes', 'NOUN'), ('stock', 'NOUN'), ('.', '.')], [('In', 'ADP'), ('1979', 'NUM'), (',', '.'), ('Hearst', 'NOUN'), ('hired', 'VERB'), ('editor', 'NOUN'), ('James', 'NOUN'), ('Bellows', 'NOUN'), (',', '.'), ('who', 'PRON'), ('*T*-48', 'X'), ('brightened', 'VERB'), ('the', 'DET'), ('editorial', 'NOUN'), ('product', 'NOUN'), ('considerably', 'ADV'), ('.', '.')], [('If', 'ADP'), ('both', 'DET'), ('agencies', 'NOUN'), ('find', 'VERB'), ('violations', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('U.S.', 'NOUN'), ('trade', 'NOUN'), ('law', 'NOUN'), (',', '.'), ('the', 'DET'), ('U.S.', 'NOUN'), ('would', 'VERB'), ('assess', 'VERB'), ('penalty', 'NOUN'), ('duties', 'NOUN'), ('on', 'ADP'), ('the', 'DET'), ('imports', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-1', 'X'), ('already', 'ADV'), ('are', 'VERB'), ('subject', 'ADJ'), ('to', 'PRT'), ('import', 'NOUN'), ('quotas', 'NOUN'), ('under', 'ADP'), ('bilateral', 'ADJ'), ('textile', 'NOUN'), ('and', 'CONJ'), ('apparel', 'NOUN'), ('trade', 'NOUN'), ('agreements', 'NOUN'), ('.', '.')]]

# %%
# Getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95949

# %%
# Get the vocabulary 
tokens = [pair[0] for pair in train_tagged_words]
V = set(tokens)
print(len(V))
# Out:
# 12106

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])
len(T)
# Out:
# 12

# %% [markdown]
# ### POS tagging algorithm - HMM
#
# Given a sequence of words, HMM algorithm assigns the most probable tag to the word. In other words, to every word w, assign the tag t that maximises the likelihood P(t/w). Since P(t/w) = P(w/t). P(t) / P(w), after ignoring P(w), we have to compute P(w/t) and P(t).
#
# P(w/t) is basically the probability that given a tag (say NN), what is the probability of it being w (say 'building'). This can be computed by computing the fraction of all NNs which are equal to w, i.e.
#
# P(w/t) = count(w, t) / count(t).
#
# The term P(t) is the probability of tag t

# %% [markdown]
# #### Compute Emission Probabilities

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# program being NOUN
print("\n", "program")
print(word_given_tag('program', 'NOUN'))
# Out:
#  program
# (120, 27539)

# %% [markdown]
# #### Compute Transition Probabilities

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))

tags_df
# Out:
#            NUM      CONJ       DET       PRT      VERB      NOUN      PRON  \
# NUM   0.184195  0.013072  0.003862  0.026144  0.016934  0.352347  0.001485
# CONJ  0.042188  0.000464  0.118683  0.003709  0.155308  0.350487  0.058414
# DET   0.021640  0.000481  0.005771  0.000240  0.040394  0.637293  0.003727
# PRT   0.056102  0.002297  0.101050  0.001969  0.405184  0.245735  0.017717
# VERB  0.022448  0.005186  0.133292  0.031427  0.168744  0.111386  0.035916
# NOUN  0.009550  0.042921  0.013363  0.043357  0.146955  0.264280  0.004721
# PRON  0.007280  0.004981  0.009195  0.012261  0.484291  0.211494  0.007663
# .     0.081353  0.058032  0.173558  0.002511  0.088708  0.222531  0.065208
# ADP   0.061910  0.000848  0.323969  0.001484  0.008481  0.321213  0.069119
# ADV   0.031624  0.006991  0.069907  0.014314  0.344541  0.031624  0.015646
# ADJ   0.020803  0.016052  0.004914  0.010156  0.011794  0.700901  0.000491
# X     0.002857  0.010316  0.055229  0.184891  0.204571  0.062371  0.055705
#
#              .       ADP       ADV       ADJ         X
# NUM   0.118835  0.035056  0.002674  0.033571  0.211824
# CONJ  0.035698  0.053778  0.053778  0.118683  0.008809
# DET   0.017913  0.009618  0.012623  0.204977  0.045323
# PRT   0.043635  0.019357  0.010171  0.083661  0.013123
# VERB  0.034291  0.091184  0.082050  0.065640  0.218438
# NOUN  0.239951  0.177058  0.016813  0.012165  0.028868
# PRON  0.040613  0.023372  0.034100  0.072031  0.092720
# .     0.092923  0.092206  0.052292  0.043681  0.026908
# ADP   0.039754  0.017492  0.013357  0.107389  0.034984
# ADV   0.135153  0.119507  0.077230  0.130160  0.023302
# ADJ   0.063882  0.078624  0.004914  0.067158  0.020311
# X     0.162831  0.144898  0.025393  0.016505  0.074433

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluation on validation set

# %%
# Running on entire validation dataset would take more than 3-4hrs. 
# Let's validation our Viterbi algorithm on a few sample sentences of validation  dataset

random.seed(1234)
# choose random 25 sents
#rndom = [random.randint(1,len(val_set)) for x in range(25)]

# list of sents
#val_run = [val_set[i] for i in rndom]
val_run = [sent for sent in val_set]

# list of tagged words
val_run_base = [tup for sent in val_run for tup in sent]

# list of untagged words
val_tagged_words = [tup[0] for sent in val_run for tup in sent]

# %%
# tagging the validation sentences
start = time.time()
tagged_seq = Viterbi(val_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)

# accuracy
check = [i for i, j in zip(tagged_seq, val_run_base) if i == j]  

accuracy = len(check)/len(tagged_seq)
print("Accuracy of the tagger: ", accuracy)
# Out:
# Time taken in seconds:  1590.2958076000214
# Accuracy of the tagger:  0.91030251745293

# %%
# Incorrectly tagged words using vanilla Viterbi based POS tagger
incorrect_tagged_cases = [[val_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, val_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('to', 'PRT'), (('book', 'NOUN'), ('book', 'VERB'))],
#  [('leaving', 'VERB'), (('stocks', 'NOUN'), ('stocks', 'ADV'))],
#  [('stocks', 'ADV'), (('up', 'PRT'), ('up', 'ADP'))],
#  [('carried', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [('apparently', 'ADV'), (('ignored', 'NUM'), ('ignored', 'VERB'))],
#  [('Chilean', 'ADJ'), (('mine', 'NOUN'), ('mine', 'ADJ'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('.', '.'), (('Preston', 'NUM'), ('Preston', 'NOUN'))],
#  [('Foster', 'NOUN'), (('Birmingham', 'NUM'), ('Birmingham', 'NOUN'))],
#  [(',', '.'), (('Ala', 'NUM'), ('Ala', 'NOUN'))],
#  [('has', 'VERB'), (('clamped', 'NUM'), ('clamped', 'VERB'))],
#  [('their', 'PRON'), (('ankle', 'NUM'), ('ankle', 'NOUN'))],
#  [('the', 'DET'), (('third-largest', 'NUM'), ('third-largest', 'ADJ'))],
#  [('the', 'DET'), (('fifth-largest', 'NUM'), ('fifth-largest', 'ADJ'))],
#  [('Charles', 'NOUN'), (('Z.', 'NUM'), ('Z.', 'NOUN'))],
#  [('Z.', 'NOUN'), (('Wick', 'NUM'), ('Wick', 'NOUN'))],
#  [('he', 'PRON'), (('argues', 'NUM'), ('argues', 'VERB'))],
#  [('*', 'X'), (('Sit', 'NUM'), ('Sit', 'VERB'))],
#  [('Sit', 'VERB'), (('down', 'PRT'), ('down', 'ADV'))],
#  [('The', 'DET'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('to', 'PRT'), (('halt', 'NOUN'), ('halt', 'VERB'))],
#  [('Dow', 'NOUN'), (('slides', 'NOUN'), ('slides', 'VERB'))],
#  [('where', 'ADV'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('as', 'ADP'), (('athletic', 'NUM'), ('athletic', 'ADJ'))],
#  [('*-2', 'X'), (('to', 'PRT'), ('to', 'ADJ'))],
#  [('1990', 'NUM'), (('better', 'ADJ'), ('better', 'ADV'))],
#  [('*ICH*-1', 'X'), (('illustrates', 'NUM'), ('illustrates', 'VERB'))],
#  [("'s", 'PRT'), (('attempt', 'VERB'), ('attempt', 'NOUN'))],
#  [('to', 'PRT'), (('usurp', 'NUM'), ('usurp', 'VERB'))],
#  [('usurp', 'VERB'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('the', 'DET'), (('executive-office', 'NUM'), ('executive-office', 'NOUN'))],
#  [(',', '.'), (('administer', 'NUM'), ('administer', 'VERB'))],
#  [('been', 'VERB'), (('disapproved', 'NUM'), ('disapproved', 'VERB'))],
#  [('disapproved', 'VERB'), (('*-58', 'NUM'), ('*-58', 'X'))],
#  [('of', 'ADP'), (('disapproval', 'NUM'), ('disapproval', 'NOUN'))],
#  [('in', 'ADP'), (('accordance', 'NUM'), ('accordance', 'NOUN'))],
#  [('the', 'DET'), (('applicable', 'NUM'), ('applicable', 'ADJ'))],
#  [("''", '.'), (('Mead', 'NUM'), ('Mead', 'NOUN'))],
#  [('Federal', 'NOUN'), (('Paper', 'NUM'), ('Paper', 'NOUN'))],
#  [('Scott', 'NOUN'), (('Paper', 'NUM'), ('Paper', 'NOUN'))],
#  [('International', 'NOUN'), (('Paper', 'NUM'), ('Paper', 'NOUN'))],
#  [('and', 'CONJ'),
#   (('Louisiana-Pacific', 'NUM'), ('Louisiana-Pacific', 'NOUN'))],
#  [('Peter', 'NOUN'), (('DeFazio', 'NUM'), ('DeFazio', 'NOUN'))],
#  [('previous', 'ADJ'), (('criteria', 'NUM'), ('criteria', 'NOUN'))],
#  [('.', '.'), (('Proper', 'NUM'), ('Proper', 'ADJ'))],
#  [('Proper', 'ADJ'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('``', '.'), (('rounds', 'NUM'), ('rounds', 'NOUN'))],
#  [('the', 'DET'), (('highest-pitched', 'NUM'), ('highest-pitched', 'ADJ'))],
#  [('simple', 'ADJ'), (('descending', 'NUM'), ('descending', 'VERB'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('62-year-old', 'NUM'), ('62-year-old', 'ADJ'))],
#  [('chief', 'NOUN'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('the', 'DET'), (('forest-product', 'NUM'), ('forest-product', 'NOUN'))],
#  [("'s", 'PRT'), (('unsolicited', 'NUM'), ('unsolicited', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('companies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('have', 'VERB'), (('diversified', 'ADJ'), ('diversified', 'VERB'))],
#  [('all', 'DET'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('impressive', 'NUM'), ('impressive', 'ADJ'))],
#  [('will', 'VERB'), (('issue', 'NOUN'), ('issue', 'VERB'))],
#  [('of', 'ADP'), (('29year', 'NUM'), ('29year', 'ADJ'))],
#  [(',', '.'), (('nine-month', 'NUM'), ('nine-month', 'ADJ'))],
#  [('bond', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('ECONOMIC', 'NUM'), ('ECONOMIC', 'ADJ'))],
#  [('ECONOMIC', 'ADJ'), (('GROWTH', 'NUM'), ('GROWTH', 'NOUN'))],
#  [('GROWTH', 'NOUN'), (('APPEARS', 'NUM'), ('APPEARS', 'VERB'))],
#  [('leveling', 'VERB'), (('off', 'PRT'), ('off', 'ADP'))],
#  [("'s", 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('Michelin', 'NOUN'), (('S.A', 'NUM'), ('S.A', 'NOUN'))],
#  [(',', '.'), (('U.S.-Japanese', 'NUM'), ('U.S.-Japanese', 'ADJ'))],
#  [('economic', 'ADJ'), (('behemoth', 'NUM'), ('behemoth', 'NOUN'))],
#  [('which', 'DET'), (('*T*-174', 'NUM'), ('*T*-174', 'X'))],
#  [('operates', 'VERB'), (('hotels', 'NUM'), ('hotels', 'NOUN'))],
#  [('rights', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-175', 'NUM'), ('*T*-175', 'X'))],
#  [('by', 'ADP'), (('masters', 'NUM'), ('masters', 'NOUN'))],
#  [('.', '.'), (('Tiny', 'NUM'), ('Tiny', 'NOUN'))],
#  [('Tiny', 'NOUN'), (('Tots', 'NUM'), ('Tots', 'NOUN'))],
#  [('is', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('*T*-2', 'X'), (('Kelli', 'NUM'), ('Kelli', 'NOUN'))],
#  [('Kelli', 'NOUN'), (('Green', 'NUM'), ('Green', 'NOUN'))],
#  [('Greenville', 'NOUN'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('to', 'PRT'), (('speculate', 'NUM'), ('speculate', 'VERB'))],
#  [('Japan', 'NOUN'), (('yen-support', 'NUM'), ('yen-support', 'ADJ'))],
#  [('yen-support', 'ADJ'), (('intervention', 'NUM'), ('intervention', 'NOUN'))],
#  [('in', 'ADP'), (('excess', 'ADJ'), ('excess', 'NOUN'))],
#  [('or', 'CONJ'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('stepping', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('no', 'DET'), (('smiles', 'NUM'), ('smiles', 'NOUN'))],
#  [(',', '.'), (('Mont', 'NUM'), ('Mont', 'NOUN'))],
#  [('the', 'DET'), (('exits', 'NUM'), ('exits', 'NOUN'))],
#  [('market', 'NOUN'), (('rebound', 'VERB'), ('rebound', 'NOUN'))],
#  [('rebound', 'NOUN'), (('pushes', 'NUM'), ('pushes', 'VERB'))],
#  [('*-1', 'X'), (('Left', 'NUM'), ('Left', 'VERB'))],
#  [('and', 'CONJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('scores', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('.', '.'), (('Sandoz', 'NUM'), ('Sandoz', 'NOUN'))],
#  [('conducting', 'VERB'), (('preclinical', 'NUM'), ('preclinical', 'ADJ'))],
#  [('``', '.'), (('vague', 'NUM'), ('vague', 'ADJ'))],
#  [('and', 'CONJ'), (('mushy', 'NUM'), ('mushy', 'ADJ'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('all', 'DET'), (('viewpoints', 'NUM'), ('viewpoints', 'NOUN'))],
#  [('come', 'VERB'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('Salon', 'NOUN'), (('le', 'NUM'), ('le', 'DET'))],
#  [('the', 'DET'), (('genie', 'NUM'), ('genie', 'NOUN'))],
#  [('genie', 'NOUN'), (('back', 'PRT'), ('back', 'ADV'))],
#  [('The', 'DET'), (('len', 'NUM'), ('len', 'NOUN'))],
#  [("'s", 'PRT'), (('foldability', 'NUM'), ('foldability', 'NOUN'))],
#  [('be', 'VERB'), (('inserted', 'NUM'), ('inserted', 'VERB'))],
#  [('smaller', 'ADJ'), (('incisions', 'NUM'), ('incisions', 'NOUN'))],
#  [('the', 'DET'), (('eye', 'NUM'), ('eye', 'NOUN'))],
#  [('skin', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('could', 'VERB'), (('clear', 'ADJ'), ('clear', 'VERB'))],
#  [('an', 'DET'), (('ethanol', 'NUM'), ('ethanol', 'NOUN'))],
#  [('to', 'PRT'), (('fuel', 'NOUN'), ('fuel', 'VERB'))],
#  [('national', 'ADJ'), (('fleet', 'NUM'), ('fleet', 'NOUN'))],
#  [('.', '.'), (('Lucille', 'NUM'), ('Lucille', 'NOUN'))],
#  [('an', 'DET'), (('84-year-old', 'NUM'), ('84-year-old', 'ADJ'))],
#  [('Chicago', 'NOUN'), (('housewife', 'NUM'), ('housewife', 'NOUN'))],
#  [('become', 'VERB'), (('amazingly', 'NUM'), ('amazingly', 'ADV'))],
#  [('stock-market', 'NOUN'), (('jolts', 'NUM'), ('jolts', 'NOUN'))],
#  [('.', '.'), (('DISCOUNT', 'NUM'), ('DISCOUNT', 'NOUN'))],
#  [('in', 'ADP'), (('sight', 'NUM'), ('sight', 'NOUN'))],
#  [('many', 'ADJ'), (('*T*-178', 'NUM'), ('*T*-178', 'X'))],
#  [('Ms.', 'NOUN'), (('Kirkpatrick', 'NUM'), ('Kirkpatrick', 'NOUN'))],
#  [('barred', 'VERB'), (('*-154', 'NUM'), ('*-154', 'X'))],
#  [('.', '.'), (('Sumitomo', 'NUM'), ('Sumitomo', 'NOUN'))],
#  [('Sumitomo', 'NOUN'), (('Metal', 'NUM'), ('Metal', 'NOUN'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('of', 'ADP'), (('readings', 'NUM'), ('readings', 'NOUN'))],
#  [('is', 'VERB'), (('wrestling', 'NUM'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'NUM'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'NUM'), ('insane', 'ADJ'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('seem', 'VERB'), (('tailor-made', 'NUM'), ('tailor-made', 'ADJ'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('The', 'DET'), (('purhasing', 'NUM'), ('purhasing', 'NOUN'))],
#  [("'", 'PRT'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('bad', 'ADJ'), (('movies', 'NUM'), ('movies', 'NOUN'))],
#  [('Gregory', 'NOUN'), (('Peck', 'NUM'), ('Peck', 'NOUN'))],
#  [('a', 'DET'), (('marvelously', 'NUM'), ('marvelously', 'ADV'))],
#  [('marvelously', 'ADV'), (('loose', 'NUM'), ('loose', 'ADJ'))],
#  [('energetic', 'ADJ'), (('portrayal', 'NUM'), ('portrayal', 'NOUN'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('.', '.'), (('Cataracts', 'NUM'), ('Cataracts', 'NOUN'))],
#  [('Cataracts', 'NOUN'), (('refer', 'NUM'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('clouding', 'NUM'), ('clouding', 'NOUN'))],
#  [('the', 'DET'), (('eye', 'NUM'), ('eye', 'NOUN'))],
#  [('sold', 'VERB'), (('*-107', 'NUM'), ('*-107', 'X'))],
#  [('raise', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('in', 'ADP'), (('maturing', 'NUM'), ('maturing', 'VERB'))],
#  [('stand', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('``', '.'), (('filled', 'NUM'), ('filled', 'VERB'))],
#  [('the', 'DET'), (('solemn', 'NUM'), ('solemn', 'ADJ'))],
#  [('solemn', 'ADJ'), (('intoxication', 'NUM'), ('intoxication', 'NOUN'))],
#  [('intoxication', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-226', 'NUM'), ('*T*-226', 'X'))],
#  [('of', 'ADP'), (('intricate', 'NUM'), ('intricate', 'ADJ'))],
#  [('intricate', 'ADJ'), (('ritual', 'NUM'), ('ritual', 'NOUN'))],
#  [('ritual', 'NOUN'), (('faultlessly', 'NUM'), ('faultlessly', 'ADV'))],
#  [('questionable', 'ADJ'), (('properties', 'NUM'), ('properties', 'NOUN'))],
#  [('.', '.'), (('Indexing', 'NUM'), ('Indexing', 'NOUN'))],
#  [('stock-market', 'NOUN'), (('barometer', 'NUM'), ('barometer', 'NOUN'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('seen', 'VERB'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('people', 'NOUN'), (('crying', 'NUM'), ('crying', 'VERB'))],
#  [('an', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('in', 'ADP'), (('Ilminster', 'NUM'), ('Ilminster', 'NOUN'))],
#  [(',', '.'), (('Somerset', 'NUM'), ('Somerset', 'NOUN'))],
#  [('silent', 'ADJ'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('a', 'DET'), (('dust-up', 'NUM'), ('dust-up', 'NOUN'))],
#  [('church', 'NOUN'), (('attendance', 'NUM'), ('attendance', 'NOUN'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('has', 'VERB'), (('shown', 'NUM'), ('shown', 'VERB'))],
#  [('shown', 'VERB'), (('no', 'X'), ('no', 'DET'))],
#  [('no', 'DET'), (('sign', 'VERB'), ('sign', 'NOUN'))],
#  [('.', '.'), (('Video', 'NUM'), ('Video', 'NOUN'))],
#  [('Video', 'NOUN'), (('Tip', 'NUM'), ('Tip', 'NOUN'))],
#  [('his', 'PRON'), (('finest', 'NUM'), ('finest', 'ADJ'))],
#  [('much', 'ADV'), (('defeats', 'NUM'), ('defeats', 'VERB'))],
#  [('any', 'DET'), (('inkling', 'NUM'), ('inkling', 'NOUN'))],
#  [('poor', 'ADJ'), (('underprivileged', 'NUM'), ('underprivileged', 'ADJ'))],
#  [('the', 'DET'), (('prosecutor', 'NUM'), ('prosecutor', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-96', 'NUM'), ('*T*-96', 'X'))],
#  [("'s", 'PRT'), (('alumni', 'NUM'), ('alumni', 'NOUN'))],
#  [('has', 'VERB'), (('cultivated', 'NUM'), ('cultivated', 'VERB'))],
#  [('a', 'DET'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('much', 'ADV'), (('savvier', 'NUM'), ('savvier', 'ADJ'))],
#  [('take', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('get', 'VERB'), (('burned', 'NUM'), ('burned', 'VERB'))],
#  [('their', 'PRON'), (('wrath', 'NUM'), ('wrath', 'NOUN'))],
#  [('conservative', 'ADJ'), (('Californian', 'NUM'), ('Californian', 'NOUN'))],
#  [('assist', 'VERB'), (('Bolivia', 'NUM'), ('Bolivia', 'NOUN'))],
#  [('then', 'ADV'), (('broadened', 'NUM'), ('broadened', 'VERB'))],
#  [('Basin', 'NOUN'), (('initiate', 'NUM'), ('initiate', 'NOUN'))],
#  [('initiate', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('Maxwell', 'NOUN'), (('R.D.', 'NUM'), ('R.D.', 'NOUN'))],
#  [('R.D.', 'NOUN'), (('Vos', 'NUM'), ('Vos', 'NOUN'))],
#  [(',', '.'), (('N.Y', 'NUM'), ('N.Y', 'NOUN'))],
#  [('were', 'VERB'), (('delayed', 'NUM'), ('delayed', 'VERB'))],
#  [('bureaucracy', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('.', '.'), (('Above', 'NUM'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('look', 'VERB'), (('around', 'ADP'), ('around', 'PRT'))],
#  [('or', 'CONJ'), (('accountants', 'NUM'), ('accountants', 'NOUN'))],
#  [('nobody', 'NOUN'), (('blinks', 'NUM'), ('blinks', 'VERB'))],
#  [('an', 'DET'), (('eye', 'NUM'), ('eye', 'NOUN'))],
#  [('can', 'VERB'), (('bar', 'NOUN'), ('bar', 'VERB'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('include', 'VERB'),
#   (('abortion-related', 'NUM'), ('abortion-related', 'ADJ'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'NUM'), ('dreamed', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'NUM'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'NUM'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NUM'), ('high-rise', 'ADJ'))],
#  [('your', 'PRON'), (('help', 'VERB'), ('help', 'NOUN'))],
#  [('giant', 'ADJ'), (('diagram', 'NUM'), ('diagram', 'NOUN'))],
#  [('with', 'ADP'), (('arrows', 'NUM'), ('arrows', 'NOUN'))],
#  [("'s", 'PRT'), (('polystyrene', 'NUM'), ('polystyrene', 'NOUN'))],
#  [('polystyrene', 'NOUN'), (('foam', 'NUM'), ('foam', 'NOUN'))],
#  [(',', '.'), (('polyproplene', 'NUM'), ('polyproplene', 'NOUN'))],
#  [('and', 'CONJ'), (('polyester', 'NUM'), ('polyester', 'NOUN'))],
#  [('all', 'DET'), (('plastic', 'ADJ'), ('plastic', 'NOUN'))],
#  [('are', 'VERB'),
#   (('non-biodegradable', 'NUM'), ('non-biodegradable', 'ADJ'))],
#  [('took', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [("'s", 'PRT'), (('seventh', 'NUM'), ('seventh', 'ADJ'))],
#  [('.', '.'), (('Researchers', 'NUM'), ('Researchers', 'NOUN'))],
#  [('at', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('materials', 'NOUN'), (('closer', 'ADV'), ('closer', 'ADJ'))],
#  [('*-1', 'X'), (('unwilling', 'NUM'), ('unwilling', 'ADJ'))],
#  [('and', 'CONJ'), (('manpower', 'NUM'), ('manpower', 'NOUN'))],
#  [('*', 'X'), (('removing', 'NUM'), ('removing', 'VERB'))],
#  [('*', 'X'), (('safeguarding', 'NUM'), ('safeguarding', 'VERB'))],
#  [('Linda', 'NOUN'), (('Anku', 'NUM'), ('Anku', 'NOUN'))],
#  [('.', '.'), (('Ketchum', 'NUM'), ('Ketchum', 'NOUN'))],
#  [('acquired', 'VERB'), (('Braun', 'NUM'), ('Braun', 'NOUN'))],
#  [('Angeles', 'NOUN'),
#   (('investor-relations', 'NUM'), ('investor-relations', 'NOUN'))],
#  [('and', 'CONJ'),
#   (('marketing-communications', 'NUM'), ('marketing-communications', 'NOUN'))],
#  [('``', '.'), (('headed', 'NUM'), ('headed', 'VERB'))],
#  [("n't", 'ADV'), (('curbed', 'NUM'), ('curbed', 'VERB'))],
#  [(',', '.'), (('index-fund', 'NOUN'), ('index-fund', 'ADJ'))],
#  [('*-1', 'X'), (('leveraging', 'NUM'), ('leveraging', 'VERB'))],
#  [('*-1', 'X'), (('owning', 'NUM'), ('owning', 'VERB'))],
#  [('to', 'PRT'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('had', 'VERB'), (('flirted', 'NUM'), ('flirted', 'VERB'))],
#  [('buyers', 'NOUN'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('barred', 'VERB'), (('*-152', 'NUM'), ('*-152', 'X'))],
#  [("'s", 'PRT'), (('father-in-law', 'NUM'), ('father-in-law', 'NOUN'))],
#  [(',', '.'), (('Gardner', 'NUM'), ('Gardner', 'NOUN'))],
#  [('G.', 'NOUN'), (('Hubbard', 'NUM'), ('Hubbard', 'NOUN'))],
#  [(',', '.'), (('wealthy', 'NUM'), ('wealthy', 'ADJ'))],
#  [('and', 'CONJ'), (('well-connected', 'NUM'), ('well-connected', 'ADJ'))],
#  [('obtained', 'VERB'), (('financing', 'VERB'), ('financing', 'NOUN'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('to', 'PRT'), (('Moon', 'NUM'), ('Moon', 'NOUN'))],
#  [('Moon', 'NOUN'), (('Landrieu', 'NUM'), ('Landrieu', 'NOUN'))],
#  [('build', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('cavernous', 'NUM'), ('cavernous', 'ADJ'))],
#  [(',', '.'), (('money-losing', 'NUM'), ('money-losing', 'ADJ'))],
#  [('*T*-2', 'X'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('little', 'ADJ'), (('relevance', 'NUM'), ('relevance', 'NOUN'))],
#  [('the', 'DET'), (('U.S.', 'NOUN'), ('U.S.', 'ADJ'))],
#  [('Tokyo', 'NOUN'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('expensive', 'ADJ'), (('cleanup', 'NUM'), ('cleanup', 'NOUN'))],
#  [('or', 'CONJ'), (('burn', 'NUM'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', 'NUM'), ('cleaner-burning', 'ADJ'))],
#  [('cleaner-burning', 'ADJ'), (('fuels', 'NUM'), ('fuels', 'NOUN'))],
#  [('market', 'NOUN'), (('overvalued', 'NUM'), ('overvalued', 'VERB'))],
#  [('.', '.'), (('Paris', 'NUM'), ('Paris', 'NOUN'))],
#  [(',', '.'), (('Brussels', 'NUM'), ('Brussels', 'NOUN'))],
#  [('and', 'CONJ'), (('Milan', 'NUM'), ('Milan', 'NOUN'))],
#  [('II', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('the', 'DET'), (('discretion', 'NUM'), ('discretion', 'NOUN'))],
#  [('to', 'PRT'), (('select', 'NUM'), ('select', 'VERB'))],
#  [(',', '.'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('an', 'DET'), (('unrestricted', 'NUM'), ('unrestricted', 'ADJ'))],
#  [('wage', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('paid', 'VERB'), (('*-165', 'NUM'), ('*-165', 'X'))],
#  [("'s", 'PRT'), (('firm', 'NOUN'), ('firm', 'ADJ'))],
#  [('steady', 'ADJ'), (('opening', 'VERB'), ('opening', 'NOUN'))],
#  [('also', 'ADV'), (('tempted', 'NUM'), ('tempted', 'VERB'))],
#  [('finished', 'VERB'), (('less', 'ADV'), ('less', 'ADJ'))],
#  [('point', 'NOUN'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('moderate', 'ADJ'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('its', 'PRON'), (('glory', 'NUM'), ('glory', 'NOUN'))],
#  [('had', 'VERB'), (('faded', 'NUM'), ('faded', 'VERB'))],
#  [('the', 'DET'), (('yellow', 'NUM'), ('yellow', 'ADJ'))],
#  [('yellow', 'ADJ'), (('bricks', 'NUM'), ('bricks', 'NOUN'))],
#  [('broad', 'ADJ'), (('facade', 'NUM'), ('facade', 'NOUN'))],
#  [('The', 'DET'), (('record', 'NOUN'), ('record', 'ADJ'))],
#  [('recently', 'ADV'), (('diagnosed', 'NUM'), ('diagnosed', 'VERB'))],
#  [('by', 'ADP'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('a', 'DET'), (('27-year', 'NUM'), ('27-year', 'ADJ'))],
#  [('the', 'DET'),
#   (('information-services', 'NUM'), ('information-services', 'NOUN'))],
#  [(',', '.'), (('Southeast', 'NOUN'), ('Southeast', 'ADJ'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('of', 'ADP'), (('cancer-causing', 'NUM'), ('cancer-causing', 'ADJ'))],
#  [('be', 'VERB'), (('outlawed', 'NUM'), ('outlawed', 'VERB'))],
#  [('departure', 'NOUN'), (('stemmed', 'NUM'), ('stemmed', 'VERB'))],
#  [("'s", 'PRT'), (('post', 'VERB'), ('post', 'NOUN'))],
#  [('board', 'NOUN'), (('directorship', 'NUM'), ('directorship', 'NOUN'))],
#  [('a', 'DET'), (('little', 'ADJ'), ('little', 'ADV'))],
#  [('little', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('precisely', 'ADV'), (('what', 'PRON'), ('what', 'DET'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-117', 'NUM'), ('*T*-117', 'X'))],
#  [('to', 'PRT'), (('uptick', 'NOUN'), ('uptick', 'VERB'))],
#  [(',', '.'), (('head', 'NOUN'), ('head', 'ADJ'))],
#  [('Israel', 'NOUN'), (('Silverman', 'NUM'), ('Silverman', 'NOUN'))],
#  [('an', 'DET'),
#   (('insurance-company', 'NUM'), ('insurance-company', 'NOUN'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('in', 'ADP'), (('jeopardy', 'NUM'), ('jeopardy', 'NOUN'))],
#  [("''", '.'), (('NEW', 'NUM'), ('NEW', 'NOUN'))],
#  [('NEW', 'NOUN'), (('ACCOUNT', 'NUM'), ('ACCOUNT', 'NOUN'))],
#  [('Lord', 'NOUN'), (('Chilver', 'NUM'), ('Chilver', 'NOUN'))],
#  [(',', '.'), (('63-year-old', 'NUM'), ('63-year-old', 'ADJ'))],
#  [('of', 'ADP'), (('English', 'ADJ'), ('English', 'NOUN'))],
#  [('China', 'NOUN'), (('Clays', 'NUM'), ('Clays', 'NOUN'))],
#  [('.', '.'), (('CoreStates', 'NUM'), ('CoreStates', 'NOUN'))],
#  [('named', 'VERB'), (('Earle', 'NUM'), ('Earle', 'NOUN'))],
#  [('Earle', 'NOUN'), (('Palmer', 'NUM'), ('Palmer', 'NOUN'))],
#  [('&', 'CONJ'), (('Spiro', 'NUM'), ('Spiro', 'NOUN'))],
#  [('*U*', 'X'), (('account', 'VERB'), ('account', 'NOUN'))],
#  [('Once', 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [(',', '.'), (('what', 'PRON'), ('what', 'DET'))],
#  [('of', 'ADP'), (('escape', 'NUM'), ('escape', 'NOUN'))],
#  [('*T*-1', 'X'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('than', 'ADP'), (('drink', 'VERB'), ('drink', 'NOUN'))],
#  [('or', 'CONJ'), (('insanity', 'NUM'), ('insanity', 'NOUN'))],
#  [('the', 'DET'), (('heirs', 'NUM'), ('heirs', 'NOUN'))],
#  [('.', '.'), (('Nylev', 'NUM'), ('Nylev', 'NOUN'))],
#  [('push', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('from', 'ADP'), (('malnutrition', 'NUM'), ('malnutrition', 'NOUN'))],
#  [(',', '.'), (('chest', 'NUM'), ('chest', 'NOUN'))],
#  [(',', '.'), (('cardiovascular', 'NUM'), ('cardiovascular', 'ADJ'))],
#  [(',', '.'), (('infectious', 'NUM'), ('infectious', 'ADJ'))],
#  [('the', 'DET'), (('aftereffects', 'NUM'), ('aftereffects', 'NOUN'))],
#  [('of', 'ADP'), (('assaults', 'NUM'), ('assaults', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-91', 'NUM'), ('*T*-91', 'X'))],
#  [('a', 'DET'), (('grandstander', 'NUM'), ('grandstander', 'NOUN'))],
#  [('U.K.', 'NOUN'), (('luxury', 'NUM'), ('luxury', 'NOUN'))],
#  [('no', 'DET'), (('guarantee', 'VERB'), ('guarantee', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'NUM'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('nearly', 'ADV'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('consumers', 'NOUN'), (('espouse', 'NUM'), ('espouse', 'VERB'))],
#  [('with', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('about', 'ADV'), (('one-third', 'NOUN'), ('one-third', 'ADJ'))],
#  [('its', 'PRON'), (('finance', 'VERB'), ('finance', 'NOUN'))],
#  [('of', 'ADP'), (('deteriorating', 'NUM'), ('deteriorating', 'VERB'))],
#  [('Donald', 'NOUN'), (('Anderson', 'NUM'), ('Anderson', 'NOUN'))],
#  [('a', 'DET'), (('59-year-old', 'NUM'), ('59-year-old', 'ADJ'))],
#  [('``', '.'), (('fluctuations', 'NUM'), ('fluctuations', 'NOUN'))],
#  [('the', 'DET'), (('heebie-jeebies', 'NUM'), ('heebie-jeebies', 'NOUN'))],
#  [('see', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('point', 'VERB'), ('point', 'NOUN'))],
#  [('*', 'X'), (('outlawing', 'NUM'), ('outlawing', 'VERB'))],
#  [('the', 'DET'), (('audit', 'VERB'), ('audit', 'NOUN'))],
#  [("'s", 'PRT'), (('stand', 'VERB'), ('stand', 'NOUN'))],
#  [('to', 'PRT'), (('display', 'NUM'), ('display', 'VERB'))],
#  [('overhead', 'ADJ'), (('projector', 'NUM'), ('projector', 'NOUN'))],
#  [('and', 'CONJ'), (('underline', 'NUM'), ('underline', 'VERB'))],
#  [(',', '.'), (('Old-House', 'NUM'), ('Old-House', 'NOUN'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('are', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('a', 'DET'), (('following', 'VERB'), ('following', 'NOUN'))],
#  [('two', 'NUM'), (('round-trip', 'NUM'), ('round-trip', 'ADJ'))],
#  [('on', 'ADP'), (('Trans', 'NUM'), ('Trans', 'NOUN'))],
#  [('Riviera', 'NOUN'), (('luxury', 'NUM'), ('luxury', 'NOUN'))],
#  [('prices', 'NOUN'), (('soaring', 'NUM'), ('soaring', 'VERB'))],
#  [('the', 'DET'), (('reclaimed', 'NUM'), ('reclaimed', 'VERB'))],
#  [("'s", 'PRT'), (('240-page', 'NUM'), ('240-page', 'ADJ'))],
#  [('the', 'DET'), (('Iran-Contra', 'NUM'), ('Iran-Contra', 'NOUN'))],
#  [('.', '.'), (('Next', 'NUM'), ('Next', 'ADJ'))],
#  [('the', 'DET'), (('Philippine', 'NUM'), ('Philippine', 'NOUN'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('be', 'VERB'), (('capped', 'ADJ'), ('capped', 'VERB'))],
#  [('by', 'ADP'), (('Philippine', 'NUM'), ('Philippine', 'ADJ'))],
#  [('President', 'NOUN'), (('Corazon', 'NUM'), ('Corazon', 'NOUN'))],
#  [('Corazon', 'NOUN'), (('Aquino', 'NUM'), ('Aquino', 'NOUN'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NOUN'))],
#  [('until', 'ADP'), (('midyear', 'NUM'), ('midyear', 'NOUN'))],
#  [("''", '.'), (('Spending', 'NUM'), ('Spending', 'NOUN'))],
#  [(',', '.'), (('nonresidential', 'NUM'), ('nonresidential', 'ADJ'))],
#  [('was', 'VERB'), (('off', 'PRT'), ('off', 'ADJ'))],
#  [('market', 'NOUN'), (('awaits', 'NUM'), ('awaits', 'VERB'))],
#  [('will', 'VERB'), (('point', 'NOUN'), ('point', 'VERB'))],
#  [('.', '.'), (('Aerospace', 'NUM'), ('Aerospace', 'NOUN'))],
#  [('earnings', 'NOUN'), (('sagged', 'NUM'), ('sagged', 'VERB'))],
#  [('lower', 'ADJ'), (('B-1B', 'ADJ'), ('B-1B', 'NOUN'))],
#  [('the', 'DET'), (('bombers', 'NUM'), ('bombers', 'NOUN'))],
#  [('rolled', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('first', 'ADJ'), (('half', 'NOUN'), ('half', 'DET'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('the', 'DET'), (('shipboard', 'NUM'), ('shipboard', 'NOUN'))],
#  [('meetings', 'NOUN'), (('next', 'ADP'), ('next', 'ADJ'))],
#  [('and', 'CONJ'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('waters', 'NOUN'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('off', 'ADP'), (('Malta', 'NUM'), ('Malta', 'NOUN'))],
#  [('.', '.'), (('NCNB', 'NUM'), ('NCNB', 'NOUN'))],
#  [('Financial', 'NOUN'), (('Connections', 'NUM'), ('Connections', 'NOUN'))],
#  [('young', 'ADJ'), (('adults', 'NUM'), ('adults', 'NOUN'))],
#  [('so', 'ADV'), (('broadly', 'NUM'), ('broadly', 'ADV'))],
#  [('broadly', 'ADV'), (('construed', 'NUM'), ('construed', 'VERB'))],
#  [('would', 'VERB'), (('emasculate', 'NUM'), ('emasculate', 'VERB'))],
#  [('and', 'CONJ'), (('swallow', 'NUM'), ('swallow', 'VERB'))],
#  [('``', '.'), (('contrary', 'NOUN'), ('contrary', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NUM'))]]

# %% [markdown]
# #### Find unknown words in validation set

# %%
# vocabulary in val set
voc_val_set = set(val_tagged_words)

# Unknown words in val set
unknown_words = (voc_val_set-V)
print(unknown_words)
# Out:
# {'movies', 'initiate', 'preclinical', 'disapproval', 'Moon', '*T*-117', 'intelligent', '550,000', '618.1', 'display', 'manpower', '62-year-old', 'high-rise', 'dreamed', '11.95', 'diagram', 'Trans', 'faultlessly', 'R.D.', 'loose', 'applicable', 'Aerospace', 'CoreStates', 'Somerset', 'NCNB', 'adults', 'clouding', 'round-trip', 'shipboard', 'cardiovascular', '306', '88.32', 'Old-House', 'le', 'ECONOMIC', '*-165', 'glory', 'descending', 'Aquino', '*-152', 'Five', 'nonresidential', 'highest-pitched', '13.90', 'Chilver', 'Ilminster', 'intervention', 'escape', 'facade', 'Z.', 'shop', 'intricate', 'directorship', 'accordance', 'Video', '609', 'heebie-jeebies', '63-year-old', 'wrath', 'diagnosed', 'cleaner-burning', 'wealthy', 'reclaimed', 'Mont', 'refer', 'Birmingham', 'leveraging', 'DeFazio', 'viewpoints', 'flirted', 'fleet', 'Corazon', 'masters', 'insanity', 'clamped', 'hotels', 'S.A', 'relevance', 'amazingly', 'owning', 'blinks', 'Four', 'broadened', '858,000', '*T*-174', 'Researchers', 'awaits', 'Californian', 'Spiro', 'improbable', 'Above', 'vague', '879', 'ritual', 'midyear', 'infectious', 'construed', 'Peck', 'abortion-related', 'eye', 'Bolivia', 'jeopardy', 'father-in-law', 'housewife', '12.52', 'investor-relations', '126,000', 'Connections', 'genie', '141.9', '8.75', 'select', 'Paris', 'third-largest', 'alumni', 'Lucille', 'cavernous', 'grandstander', 'Anderson', 'finest', 'curbed', 'broadly', 'Gardner', 'bricks', 'barometer', 'Milan', 'behemoth', 'marketing-communications', 'unwilling', 'marvelously', 'inserted', 'readings', 'Brussels', 'defeats', 'sight', 'swallow', '115', 'discretion', 'well-connected', 'wrestling', 'exits', 'intoxication', 'Indexing', '59-year-old', 'ACCOUNT', '1997', 'filled', 'N.Y', 'information-services', '84-year-old', 'impressive', 'Iran-Contra', 'Proper', 'soaring', 'burned', '960', 'Sit', 'Paper', 'headed', "'82", 'len', 'insurance-company', '*T*-226', 'non-biodegradable', '99.1', 'administer', '692', 'Wick', 'cultivated', 'aftereffects', '149.9', 'luxury', '29year', 'malnutrition', 'safeguarding', 'Preston', 'solemn', 'burn', 'portrayal', 'shown', 'Philippine', 'unsolicited', 'overvalued', 'projector', 'athletic', 'cleanup', 'criteria', 'fifth-largest', '*T*-91', 'crying', '143.08', 'mushy', 'yellow', 'Metal', 'stemmed', 'Green', 'Ketchum', 'Tots', 'chest', 'seventh', 'Tip', 'polyester', 'Louisiana-Pacific', 'sagged', 'incisions', 'heirs', 'GROWTH', '240-page', 'illustrates', 'Silverman', '*T*-96', 'disapproved', 'Sumitomo', 'bombers', 'delayed', 'fuels', 'ankle', '*-107', 'accountants', 'smiles', 'arrows', 'NEW', '221.4', 'Palmer', '*T*-178', 'foam', 'Hubbard', '51.6', '14.75', 'unrestricted', 'jolts', 'APPEARS', 'tailor-made', 'money-losing', '*-154', 'Landrieu', '27-year', 'foldability', 'speculate', 'emasculate', '143.93', 'assaults', '89.7', 'Kirkpatrick', 'purhasing', 'attendance', 'DISCOUNT', 'inkling', 'removing', '77.6', 'faded', '*T*-175', 'U.S.-Japanese', 'ethanol', 'Mead', '150.00', 'outlawed', 'properties', 'Spending', 'Tiny', 'yen-support', 'Next', 'rounds', 'Malta', 'underprivileged', 'tempted', 'shopped', 'Kelli', '3.19', 'Nylev', 'dust-up', 'argues', 'executive-office', '472', 'maturing', 'polystyrene', 'fluctuations', 'nine-month', '*-58', 'pushes', 'espouse', 'ignored', 'Braun', 'deteriorating', 'Vos', 'Cataracts', 'underline', 'prosecutor', 'cancer-causing', 'insane', 'savvier', 'Clays', 'polyproplene', '94.8', 'Ala', 'forest-product', 'usurp', 'Sandoz', 'Earle', 'Anku', 'outlawing', 'Left'}

# %% [markdown]
# #### Unknown word observations
# 1. The unknown words like 'outlawing', 'safeguarding' and 'Indexing' which are verbs most of the times are tagged as 'NOUN'
# 2. The unknown words like 'broadened', 'shopped' and 'delayed' which are verbs most of the times are tagged as 'NOUN'
# 3. The unknown words like 'argues' and 'illustrates' which are verbs most of the times are tagged as 'NOUN'
# 4. The unknown words like 'third-largest' and 'finest' which are adjectives most of the times are tagged as 'NOUN'
# 5. The unknown words like 'broadly' and 'faultlessly' which are adverbs most of the times are tagged as 'NOUN'
# 6. Most of the decimal numbers are tagged as 'NOUN' instead of 'NUM'

# %% [markdown]
# #### Handling unknown words
#
# The Viterbi algorithm tags the unknown words with the most frequently occuring POS tag('PRON') as the emission probability is zero.
#
# The Performance of the POS tagger can be improved by modifying the viterbi algorithm in two ways listed below.
# 1. By using rule based tagger for unknown words using morphological rules
# 2. By using the probability based technique, forcing emission probability to a small value (i.e 0.001)

# %% [markdown]
# ### Solve the problem of unknown words

# %%
# Modified Viterbi Heuristic with rule based backoff
def Viterbi_backedoff_with_rule_based(words, train_bag = train_tagged_words, vocabulary=V):
    # Rule based tagger
    # specify patterns for tagging
    patterns = [
        (r'.*ing$', 'VERB'),              # gerund
        (r'.*ed$', 'VERB'),               # past tense
        (r'.*es$', 'VERB'),               # 3rd singular present
        (r'.*er$', 'ADJ'),                # adjectives
        (r'.*est$', 'ADJ'),               # adjectives
        (r'.*able$', 'ADJ'),              # adjectives
        (r'.*ly$', 'ADV'),                # adverbs
        (r'.*\'s$', 'NOUN'),              # possessive nouns
        (r'.*s$', 'NOUN'),                # plural nouns
        (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
        (r'\*T?\*?-[0-9]+$', 'X'),        # X
        (r'(The|the|A|a|An|an)$', 'DET'), # articles
        (r'.*', 'NOUN')                   # nouns
    ]
    regexp_tagger = nltk.RegexpTagger(patterns)
    
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        state_max = 'NOUN'
        if (word in vocabulary):
            #initialise list of probability column for a given observation
            p = [] 
            for tag in T:
                if key == 0:
                    transition_p = tags_df.loc['.', tag]
                else:
                    transition_p = tags_df.loc[state[-1], tag]

                # compute emission and state probabilities
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
                state_probability = emission_p * transition_p    
                p.append(state_probability)

            pmax = max(p)
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)] 
        else: 
            # Rule based tagging
            pos_tag = regexp_tagger.tag([word])
            state_max = pos_tag[0][1]
            
        state.append(state_max)
    return list(zip(words, state))

# %%
# Viterbi Heuristic backed off with probability technique
def Viterbi_backedoff_with_probability_technique(words, train_bag = train_tagged_words, vocabulary=V):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            if (word in vocabulary):
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            else:
                emission_p = 0.001
            
            state_probability = emission_p * transition_p
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy of modified viterbi using rule based technique

# %%
# tagging the validation sentences
start = time.time()
tagged_seq = Viterbi_backedoff_with_rule_based(val_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)

# accuracy
check = [i for i, j in zip(tagged_seq, val_run_base) if i == j]  

accuracy = len(check)/len(tagged_seq)
print("Accuracy of the tagger: ", accuracy)
# Out:
# Time taken in seconds:  862.9099161624908
# Accuracy of the tagger:  0.9494393907340808

# %%
# Incorrectly tagged words using modified Viterbi based POS tagger using rule based technique
incorrect_tagged_cases = [[val_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, val_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('to', 'PRT'), (('book', 'NOUN'), ('book', 'VERB'))],
#  [('leaving', 'VERB'), (('stocks', 'NOUN'), ('stocks', 'ADV'))],
#  [('stocks', 'ADV'), (('up', 'PRT'), ('up', 'ADP'))],
#  [('carried', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [('Chilean', 'ADJ'), (('mine', 'NOUN'), ('mine', 'ADJ'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('*', 'X'), (('Sit', 'NOUN'), ('Sit', 'VERB'))],
#  [('Sit', 'VERB'), (('down', 'ADP'), ('down', 'ADV'))],
#  [('The', 'DET'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('to', 'PRT'), (('halt', 'NOUN'), ('halt', 'VERB'))],
#  [('Dow', 'NOUN'), (('slides', 'NOUN'), ('slides', 'VERB'))],
#  [('where', 'ADV'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('as', 'ADP'), (('athletic', 'NOUN'), ('athletic', 'ADJ'))],
#  [('*-2', 'X'), (('to', 'PRT'), ('to', 'ADJ'))],
#  [('1990', 'NUM'), (('better', 'ADJ'), ('better', 'ADV'))],
#  [("'s", 'PRT'), (('attempt', 'VERB'), ('attempt', 'NOUN'))],
#  [('to', 'PRT'), (('usurp', 'NOUN'), ('usurp', 'VERB'))],
#  [('usurp', 'VERB'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [(',', '.'), (('administer', 'ADJ'), ('administer', 'VERB'))],
#  [('Federal', 'NOUN'), (('Paper', 'ADJ'), ('Paper', 'NOUN'))],
#  [('Scott', 'NOUN'), (('Paper', 'ADJ'), ('Paper', 'NOUN'))],
#  [('International', 'NOUN'), (('Paper', 'ADJ'), ('Paper', 'NOUN'))],
#  [('.', '.'), (('Five', 'NOUN'), ('Five', 'NUM'))],
#  [('Proper', 'ADJ'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('the', 'DET'), (('highest-pitched', 'VERB'), ('highest-pitched', 'ADJ'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('62-year-old', 'NOUN'), ('62-year-old', 'ADJ'))],
#  [('chief', 'NOUN'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [("'s", 'PRT'), (('unsolicited', 'VERB'), ('unsolicited', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('companies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('have', 'VERB'), (('diversified', 'ADJ'), ('diversified', 'VERB'))],
#  [('all', 'DET'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('impressive', 'NOUN'), ('impressive', 'ADJ'))],
#  [('will', 'VERB'), (('issue', 'NOUN'), ('issue', 'VERB'))],
#  [('of', 'ADP'), (('29year', 'NOUN'), ('29year', 'ADJ'))],
#  [(',', '.'), (('nine-month', 'NOUN'), ('nine-month', 'ADJ'))],
#  [('bond', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('ECONOMIC', 'NOUN'), ('ECONOMIC', 'ADJ'))],
#  [('GROWTH', 'NOUN'), (('APPEARS', 'NOUN'), ('APPEARS', 'VERB'))],
#  [('leveling', 'VERB'), (('off', 'PRT'), ('off', 'ADP'))],
#  [("'s", 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('U.S.-Japanese', 'NOUN'), ('U.S.-Japanese', 'ADJ'))],
#  [('rights', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('is', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('Greenville', 'NOUN'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('to', 'PRT'), (('speculate', 'NOUN'), ('speculate', 'VERB'))],
#  [('Japan', 'NOUN'), (('yen-support', 'NOUN'), ('yen-support', 'ADJ'))],
#  [('in', 'ADP'), (('excess', 'ADJ'), ('excess', 'NOUN'))],
#  [('or', 'CONJ'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('stepping', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('no', 'DET'), (('smiles', 'VERB'), ('smiles', 'NOUN'))],
#  [('market', 'NOUN'), (('rebound', 'VERB'), ('rebound', 'NOUN'))],
#  [('*-1', 'X'), (('Left', 'NOUN'), ('Left', 'VERB'))],
#  [('and', 'CONJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('scores', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('conducting', 'VERB'), (('preclinical', 'NOUN'), ('preclinical', 'ADJ'))],
#  [('``', '.'), (('vague', 'NOUN'), ('vague', 'ADJ'))],
#  [('and', 'CONJ'), (('mushy', 'NOUN'), ('mushy', 'ADJ'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('come', 'VERB'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('Salon', 'NOUN'), (('le', 'NOUN'), ('le', 'DET'))],
#  [('genie', 'NOUN'), (('back', 'PRT'), ('back', 'ADV'))],
#  [('eye', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('skin', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('could', 'VERB'), (('clear', 'ADJ'), ('clear', 'VERB'))],
#  [('to', 'PRT'), (('fuel', 'NOUN'), ('fuel', 'VERB'))],
#  [('an', 'DET'), (('84-year-old', 'NOUN'), ('84-year-old', 'ADJ'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('especially', 'ADV'), (('intelligent', 'NOUN'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'NOUN'), ('insane', 'ADJ'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('seem', 'VERB'), (('tailor-made', 'NOUN'), ('tailor-made', 'ADJ'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('The', 'DET'), (('purhasing', 'VERB'), ('purhasing', 'NOUN'))],
#  [("'", 'PRT'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('bad', 'ADJ'), (('movies', 'VERB'), ('movies', 'NOUN'))],
#  [('marvelously', 'ADV'), (('loose', 'NOUN'), ('loose', 'ADJ'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('Cataracts', 'NOUN'), (('refer', 'ADJ'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('clouding', 'VERB'), ('clouding', 'NOUN'))],
#  [('raise', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('stand', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('the', 'DET'), (('solemn', 'NOUN'), ('solemn', 'ADJ'))],
#  [('intoxication', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('of', 'ADP'), (('intricate', 'NOUN'), ('intricate', 'ADJ'))],
#  [('questionable', 'ADJ'), (('properties', 'VERB'), ('properties', 'NOUN'))],
#  [('.', '.'), (('Indexing', 'VERB'), ('Indexing', 'NOUN'))],
#  [('stock-market', 'NOUN'), (('barometer', 'ADJ'), ('barometer', 'NOUN'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('seen', 'VERB'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('an', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('in', 'ADP'), (('Ilminster', 'ADJ'), ('Ilminster', 'NOUN'))],
#  [('silent', 'ADJ'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('has', 'VERB'), (('shown', 'NOUN'), ('shown', 'VERB'))],
#  [('much', 'ADV'), (('defeats', 'NOUN'), ('defeats', 'VERB'))],
#  [('any', 'DET'), (('inkling', 'VERB'), ('inkling', 'NOUN'))],
#  [('poor', 'ADJ'), (('underprivileged', 'VERB'), ('underprivileged', 'ADJ'))],
#  [('a', 'DET'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('take', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('initiate', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('bureaucracy', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('.', '.'), (('Above', 'NOUN'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('look', 'VERB'), (('around', 'ADP'), ('around', 'PRT'))],
#  [('nobody', 'NOUN'), (('blinks', 'NOUN'), ('blinks', 'VERB'))],
#  [('can', 'VERB'), (('bar', 'NOUN'), ('bar', 'VERB'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('include', 'VERB'),
#   (('abortion-related', 'VERB'), ('abortion-related', 'ADJ'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('dreamed', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NOUN'), ('high-rise', 'ADJ'))],
#  [('your', 'PRON'), (('help', 'VERB'), ('help', 'NOUN'))],
#  [('and', 'CONJ'), (('polyester', 'ADJ'), ('polyester', 'NOUN'))],
#  [('all', 'DET'), (('plastic', 'ADJ'), ('plastic', 'NOUN'))],
#  [('took', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [("'s", 'PRT'), (('seventh', 'NOUN'), ('seventh', 'ADJ'))],
#  [('The', 'DET'), (("'82", 'NOUN'), ("'82", 'NUM'))],
#  [('at', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('materials', 'NOUN'), (('closer', 'ADV'), ('closer', 'ADJ'))],
#  [('*-1', 'X'), (('unwilling', 'VERB'), ('unwilling', 'ADJ'))],
#  [('and', 'CONJ'), (('manpower', 'ADJ'), ('manpower', 'NOUN'))],
#  [(',', '.'), (('index-fund', 'NOUN'), ('index-fund', 'ADJ'))],
#  [('owning', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('to', 'PRT'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('buyers', 'NOUN'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [(',', '.'), (('Gardner', 'ADJ'), ('Gardner', 'NOUN'))],
#  [(',', '.'), (('wealthy', 'NOUN'), ('wealthy', 'ADJ'))],
#  [('and', 'CONJ'), (('well-connected', 'VERB'), ('well-connected', 'ADJ'))],
#  [('obtained', 'VERB'), (('financing', 'VERB'), ('financing', 'NOUN'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('build', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('cavernous', 'NOUN'), ('cavernous', 'ADJ'))],
#  [(',', '.'), (('money-losing', 'VERB'), ('money-losing', 'ADJ'))],
#  [('*T*-2', 'X'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('the', 'DET'), (('U.S.', 'NOUN'), ('U.S.', 'ADJ'))],
#  [('Tokyo', 'NOUN'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('or', 'CONJ'), (('burn', 'NOUN'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', 'VERB'), ('cleaner-burning', 'ADJ'))],
#  [('II', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('select', 'NOUN'), ('select', 'VERB'))],
#  [(',', '.'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('an', 'DET'), (('unrestricted', 'VERB'), ('unrestricted', 'ADJ'))],
#  [('wage', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('firm', 'NOUN'), ('firm', 'ADJ'))],
#  [('steady', 'ADJ'), (('opening', 'VERB'), ('opening', 'NOUN'))],
#  [('finished', 'VERB'), (('less', 'ADV'), ('less', 'ADJ'))],
#  [('point', 'NOUN'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('moderate', 'ADJ'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('the', 'DET'), (('yellow', 'NOUN'), ('yellow', 'ADJ'))],
#  [('The', 'DET'), (('record', 'NOUN'), ('record', 'ADJ'))],
#  [('.', '.'), (('Four', 'NOUN'), ('Four', 'NUM'))],
#  [('by', 'ADP'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('a', 'DET'), (('27-year', 'NOUN'), ('27-year', 'ADJ'))],
#  [('the', 'DET'),
#   (('information-services', 'VERB'), ('information-services', 'NOUN'))],
#  [(',', '.'), (('Southeast', 'NOUN'), ('Southeast', 'ADJ'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('of', 'ADP'), (('cancer-causing', 'VERB'), ('cancer-causing', 'ADJ'))],
#  [("'s", 'PRT'), (('post', 'VERB'), ('post', 'NOUN'))],
#  [('a', 'DET'), (('little', 'ADJ'), ('little', 'ADV'))],
#  [('little', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('precisely', 'ADV'), (('what', 'PRON'), ('what', 'DET'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('uptick', 'NOUN'), ('uptick', 'VERB'))],
#  [(',', '.'), (('head', 'NOUN'), ('head', 'ADJ'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('Lord', 'NOUN'), (('Chilver', 'ADJ'), ('Chilver', 'NOUN'))],
#  [(',', '.'), (('63-year-old', 'NOUN'), ('63-year-old', 'ADJ'))],
#  [('of', 'ADP'), (('English', 'ADJ'), ('English', 'NOUN'))],
#  [('.', '.'), (('CoreStates', 'VERB'), ('CoreStates', 'NOUN'))],
#  [('Earle', 'NOUN'), (('Palmer', 'ADJ'), ('Palmer', 'NOUN'))],
#  [('*U*', 'X'), (('account', 'VERB'), ('account', 'NOUN'))],
#  [('Once', 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [(',', '.'), (('what', 'PRON'), ('what', 'DET'))],
#  [('*T*-1', 'X'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('than', 'ADP'), (('drink', 'VERB'), ('drink', 'NOUN'))],
#  [('push', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [(',', '.'), (('chest', 'ADJ'), ('chest', 'NOUN'))],
#  [(',', '.'), (('cardiovascular', 'NOUN'), ('cardiovascular', 'ADJ'))],
#  [(',', '.'), (('infectious', 'NOUN'), ('infectious', 'ADJ'))],
#  [('a', 'DET'), (('grandstander', 'ADJ'), ('grandstander', 'NOUN'))],
#  [('no', 'DET'), (('guarantee', 'VERB'), ('guarantee', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('nearly', 'ADV'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('consumers', 'NOUN'), (('espouse', 'NOUN'), ('espouse', 'VERB'))],
#  [('with', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('about', 'ADV'), (('one-third', 'NOUN'), ('one-third', 'ADJ'))],
#  [('its', 'PRON'), (('finance', 'VERB'), ('finance', 'NOUN'))],
#  [('a', 'DET'), (('59-year-old', 'NOUN'), ('59-year-old', 'ADJ'))],
#  [('the', 'DET'), (('heebie-jeebies', 'VERB'), ('heebie-jeebies', 'NOUN'))],
#  [('see', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('point', 'VERB'), ('point', 'NOUN'))],
#  [('the', 'DET'), (('audit', 'VERB'), ('audit', 'NOUN'))],
#  [("'s", 'PRT'), (('stand', 'VERB'), ('stand', 'NOUN'))],
#  [('to', 'PRT'), (('display', 'NOUN'), ('display', 'VERB'))],
#  [('and', 'CONJ'), (('underline', 'NOUN'), ('underline', 'VERB'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('are', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('a', 'DET'), (('following', 'VERB'), ('following', 'NOUN'))],
#  [('two', 'NUM'), (('round-trip', 'NOUN'), ('round-trip', 'ADJ'))],
#  [("'s", 'PRT'), (('240-page', 'NOUN'), ('240-page', 'ADJ'))],
#  [('.', '.'), (('Next', 'NOUN'), ('Next', 'ADJ'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('be', 'VERB'), (('capped', 'ADJ'), ('capped', 'VERB'))],
#  [('by', 'ADP'), (('Philippine', 'NOUN'), ('Philippine', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NOUN'))],
#  [("''", '.'), (('Spending', 'VERB'), ('Spending', 'NOUN'))],
#  [(',', '.'), (('nonresidential', 'NOUN'), ('nonresidential', 'ADJ'))],
#  [('was', 'VERB'), (('off', 'PRT'), ('off', 'ADJ'))],
#  [('market', 'NOUN'), (('awaits', 'NOUN'), ('awaits', 'VERB'))],
#  [('will', 'VERB'), (('point', 'NOUN'), ('point', 'VERB'))],
#  [('lower', 'ADJ'), (('B-1B', 'ADJ'), ('B-1B', 'NOUN'))],
#  [('rolled', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('first', 'ADJ'), (('half', 'NOUN'), ('half', 'DET'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('meetings', 'NOUN'), (('next', 'ADP'), ('next', 'ADJ'))],
#  [('and', 'CONJ'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('waters', 'NOUN'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('would', 'VERB'), (('emasculate', 'NOUN'), ('emasculate', 'VERB'))],
#  [('and', 'CONJ'), (('swallow', 'NOUN'), ('swallow', 'VERB'))],
#  [('``', '.'), (('contrary', 'NOUN'), ('contrary', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NUM'))]]

# %% [markdown]
# #### Evaluating tagging accuracy of modified viterbi using probability based technique

# %%
# tagging the validation sentences
start = time.time()
tagged_seq = Viterbi_backedoff_with_probability_technique(val_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)

# accuracy
check = [i for i, j in zip(tagged_seq, val_run_base) if i == j] 

accuracy = len(check)/len(tagged_seq)
print("Accuracy of the tagger: ", accuracy)
# Out:
# Time taken in seconds:  579.2316379547119
# Accuracy of the tagger:  0.9331499894224666

# %%
# Incorrectly tagged words using modified Viterbi based POS tagger using probability based technique
incorrect_tagged_cases = [[val_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, val_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('to', 'PRT'), (('book', 'NOUN'), ('book', 'VERB'))],
#  [('leaving', 'VERB'), (('stocks', 'NOUN'), ('stocks', 'ADV'))],
#  [('stocks', 'ADV'), (('up', 'PRT'), ('up', 'ADP'))],
#  [('carried', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [('Chilean', 'ADJ'), (('mine', 'NOUN'), ('mine', 'ADJ'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('has', 'VERB'), (('clamped', 'X'), ('clamped', 'VERB'))],
#  [('their', 'PRON'), (('ankle', 'VERB'), ('ankle', 'NOUN'))],
#  [('the', 'DET'), (('third-largest', 'NOUN'), ('third-largest', 'ADJ'))],
#  [('the', 'DET'), (('fifth-largest', 'NOUN'), ('fifth-largest', 'ADJ'))],
#  [('#', '.'), (('89.7', 'NOUN'), ('89.7', 'NUM'))],
#  [('$', '.'), (('141.9', 'NOUN'), ('141.9', 'NUM'))],
#  [('#', '.'), (('94.8', 'NOUN'), ('94.8', 'NUM'))],
#  [('$', '.'), (('149.9', 'NOUN'), ('149.9', 'NUM'))],
#  [('The', 'DET'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('to', 'PRT'), (('halt', 'NOUN'), ('halt', 'VERB'))],
#  [('Dow', 'NOUN'), (('slides', 'NOUN'), ('slides', 'VERB'))],
#  [('where', 'ADV'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('as', 'ADP'), (('athletic', 'DET'), ('athletic', 'ADJ'))],
#  [('*-2', 'X'), (('to', 'PRT'), ('to', 'ADJ'))],
#  [('1990', 'NUM'), (('better', 'ADJ'), ('better', 'ADV'))],
#  [("'s", 'PRT'), (('attempt', 'VERB'), ('attempt', 'NOUN'))],
#  [('Section', 'NOUN'), (('609', 'NOUN'), ('609', 'NUM'))],
#  [(',', '.'), (('administer', 'NOUN'), ('administer', 'VERB'))],
#  [('been', 'VERB'), (('disapproved', 'X'), ('disapproved', 'VERB'))],
#  [('disapproved', 'VERB'), (('*-58', 'VERB'), ('*-58', 'X'))],
#  [('of', 'ADP'), (('disapproval', 'DET'), ('disapproval', 'NOUN'))],
#  [('in', 'ADP'), (('accordance', 'DET'), ('accordance', 'NOUN'))],
#  [('the', 'DET'), (('applicable', 'NOUN'), ('applicable', 'ADJ'))],
#  [('.', '.'), (('Five', 'NOUN'), ('Five', 'NUM'))],
#  [('.', '.'), (('Proper', 'NOUN'), ('Proper', 'ADJ'))],
#  [('Proper', 'ADJ'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('the', 'DET'), (('highest-pitched', 'NOUN'), ('highest-pitched', 'ADJ'))],
#  [('simple', 'ADJ'), (('descending', 'NOUN'), ('descending', 'VERB'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('62-year-old', 'NOUN'), ('62-year-old', 'ADJ'))],
#  [('chief', 'NOUN'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [("'s", 'PRT'), (('unsolicited', 'VERB'), ('unsolicited', 'ADJ'))],
#  [('$', '.'), (('3.19', 'NOUN'), ('3.19', 'NUM'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('companies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('have', 'VERB'), (('diversified', 'ADJ'), ('diversified', 'VERB'))],
#  [('all', 'DET'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('impressive', 'DET'), ('impressive', 'ADJ'))],
#  [('will', 'VERB'), (('issue', 'NOUN'), ('issue', 'VERB'))],
#  [('of', 'ADP'), (('29year', 'DET'), ('29year', 'ADJ'))],
#  [(',', '.'), (('nine-month', 'NOUN'), ('nine-month', 'ADJ'))],
#  [('bond', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('ECONOMIC', 'NOUN'), ('ECONOMIC', 'ADJ'))],
#  [('GROWTH', 'NOUN'), (('APPEARS', 'NOUN'), ('APPEARS', 'VERB'))],
#  [('leveling', 'VERB'), (('off', 'PRT'), ('off', 'ADP'))],
#  [("'s", 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('U.S.-Japanese', 'NOUN'), ('U.S.-Japanese', 'ADJ'))],
#  [('which', 'DET'), (('*T*-174', 'NOUN'), ('*T*-174', 'X'))],
#  [('operates', 'VERB'), (('hotels', 'X'), ('hotels', 'NOUN'))],
#  [('rights', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-175', 'DET'), ('*T*-175', 'X'))],
#  [('by', 'ADP'), (('masters', 'DET'), ('masters', 'NOUN'))],
#  [('is', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('*T*-2', 'X'), (('Kelli', 'VERB'), ('Kelli', 'NOUN'))],
#  [('Kelli', 'NOUN'), (('Green', 'X'), ('Green', 'NOUN'))],
#  [('Greenville', 'NOUN'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('Japan', 'NOUN'), (('yen-support', 'NOUN'), ('yen-support', 'ADJ'))],
#  [('the', 'DET'), (('150.00', 'NOUN'), ('150.00', 'NUM'))],
#  [('in', 'ADP'), (('excess', 'ADJ'), ('excess', 'NOUN'))],
#  [('or', 'CONJ'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('stepping', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('market', 'NOUN'), (('rebound', 'VERB'), ('rebound', 'NOUN'))],
#  [('rebound', 'NOUN'), (('pushes', 'X'), ('pushes', 'VERB'))],
#  [('and', 'CONJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('scores', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('conducting', 'VERB'), (('preclinical', 'X'), ('preclinical', 'ADJ'))],
#  [('``', '.'), (('vague', 'NOUN'), ('vague', 'ADJ'))],
#  [('and', 'CONJ'), (('mushy', 'NOUN'), ('mushy', 'ADJ'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('come', 'VERB'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('Salon', 'NOUN'), (('le', 'NOUN'), ('le', 'DET'))],
#  [('$', '.'), (('115', 'NOUN'), ('115', 'NUM'))],
#  [('genie', 'NOUN'), (('back', 'PRT'), ('back', 'ADV'))],
#  [("'s", 'PRT'), (('foldability', 'VERB'), ('foldability', 'NOUN'))],
#  [('be', 'VERB'), (('inserted', 'X'), ('inserted', 'VERB'))],
#  [('eye', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('skin', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('could', 'VERB'), (('clear', 'ADJ'), ('clear', 'VERB'))],
#  [('to', 'PRT'), (('fuel', 'NOUN'), ('fuel', 'VERB'))],
#  [('an', 'DET'), (('84-year-old', 'NOUN'), ('84-year-old', 'ADJ'))],
#  [('become', 'VERB'), (('amazingly', 'X'), ('amazingly', 'ADV'))],
#  [('in', 'ADP'), (('sight', 'DET'), ('sight', 'NOUN'))],
#  [('many', 'ADJ'), (('*T*-178', 'NOUN'), ('*T*-178', 'X'))],
#  [('to', 'PRT'), (('692', 'VERB'), ('692', 'NUM'))],
#  [('to', 'PRT'), (('960', 'VERB'), ('960', 'NUM'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('to', 'PRT'), (('51.6', 'VERB'), ('51.6', 'NUM'))],
#  [('of', 'ADP'), (('readings', 'DET'), ('readings', 'NOUN'))],
#  [('is', 'VERB'), (('wrestling', 'X'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'VERB'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'VERB'), ('insane', 'ADJ'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('seem', 'VERB'), (('tailor-made', 'X'), ('tailor-made', 'ADJ'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('a', 'DET'), (('marvelously', 'NOUN'), ('marvelously', 'ADV'))],
#  [('marvelously', 'ADV'), (('loose', 'NOUN'), ('loose', 'ADJ'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('Cataracts', 'NOUN'), (('refer', 'NOUN'), ('refer', 'VERB'))],
#  [('raise', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('in', 'ADP'), (('maturing', 'DET'), ('maturing', 'VERB'))],
#  [('stand', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('``', '.'), (('filled', 'NOUN'), ('filled', 'VERB'))],
#  [('the', 'DET'), (('solemn', 'NOUN'), ('solemn', 'ADJ'))],
#  [('intoxication', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-226', 'DET'), ('*T*-226', 'X'))],
#  [('of', 'ADP'), (('intricate', 'DET'), ('intricate', 'ADJ'))],
#  [('ritual', 'NOUN'), (('faultlessly', 'NOUN'), ('faultlessly', 'ADV'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('seen', 'VERB'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('people', 'NOUN'), (('crying', 'NOUN'), ('crying', 'VERB'))],
#  [('an', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('in', 'ADP'), (('Ilminster', 'DET'), ('Ilminster', 'NOUN'))],
#  [('silent', 'ADJ'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('to', 'PRT'), (('8.75', 'VERB'), ('8.75', 'NUM'))],
#  [('has', 'VERB'), (('shown', 'X'), ('shown', 'VERB'))],
#  [('his', 'PRON'), (('finest', 'VERB'), ('finest', 'ADJ'))],
#  [('$', '.'), (('472', 'NOUN'), ('472', 'NUM'))],
#  [('poor', 'ADJ'), (('underprivileged', 'NOUN'), ('underprivileged', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-96', 'VERB'), ('*T*-96', 'X'))],
#  [("'s", 'PRT'), (('alumni', 'VERB'), ('alumni', 'NOUN'))],
#  [('has', 'VERB'), (('cultivated', 'X'), ('cultivated', 'VERB'))],
#  [('a', 'DET'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('much', 'ADV'), (('savvier', 'NOUN'), ('savvier', 'ADJ'))],
#  [('take', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('get', 'VERB'), (('burned', 'X'), ('burned', 'VERB'))],
#  [('their', 'PRON'), (('wrath', 'VERB'), ('wrath', 'NOUN'))],
#  [('assist', 'VERB'), (('Bolivia', 'X'), ('Bolivia', 'NOUN'))],
#  [('initiate', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('were', 'VERB'), (('delayed', 'X'), ('delayed', 'VERB'))],
#  [('bureaucracy', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('.', '.'), (('Above', 'NOUN'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('look', 'VERB'), (('around', 'ADP'), ('around', 'PRT'))],
#  [('nobody', 'NOUN'), (('blinks', 'NOUN'), ('blinks', 'VERB'))],
#  [('can', 'VERB'), (('bar', 'NOUN'), ('bar', 'VERB'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('include', 'VERB'),
#   (('abortion-related', 'X'), ('abortion-related', 'ADJ'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'NOUN'), ('dreamed', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'VERB'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'VERB'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NOUN'), ('high-rise', 'ADJ'))],
#  [('your', 'PRON'), (('help', 'VERB'), ('help', 'NOUN'))],
#  [('with', 'ADP'), (('arrows', 'DET'), ('arrows', 'NOUN'))],
#  [("'s", 'PRT'), (('polystyrene', 'VERB'), ('polystyrene', 'NOUN'))],
#  [('polystyrene', 'NOUN'), (('foam', 'X'), ('foam', 'NOUN'))],
#  [('all', 'DET'), (('plastic', 'ADJ'), ('plastic', 'NOUN'))],
#  [('are', 'VERB'), (('non-biodegradable', 'X'), ('non-biodegradable', 'ADJ'))],
#  [('took', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [("'s", 'PRT'), (('seventh', 'VERB'), ('seventh', 'ADJ'))],
#  [('seventh', 'ADJ'), (('principal', 'ADJ'), ('principal', 'NOUN'))],
#  [('The', 'DET'), (("'82", 'NOUN'), ("'82", 'NUM'))],
#  [('$', '.'), (('115', 'NOUN'), ('115', 'NUM'))],
#  [('at', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('materials', 'NOUN'), (('closer', 'ADV'), ('closer', 'ADJ'))],
#  [('*-1', 'X'), (('unwilling', 'VERB'), ('unwilling', 'ADJ'))],
#  [('acquired', 'VERB'), (('Braun', 'X'), ('Braun', 'NOUN'))],
#  [('``', '.'), (('headed', 'NOUN'), ('headed', 'VERB'))],
#  [(',', '.'), (('index-fund', 'NOUN'), ('index-fund', 'ADJ'))],
#  [('owning', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('to', 'PRT'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('had', 'VERB'), (('flirted', 'X'), ('flirted', 'VERB'))],
#  [('buyers', 'NOUN'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [("'s", 'PRT'), (('father-in-law', 'VERB'), ('father-in-law', 'NOUN'))],
#  [(',', '.'), (('wealthy', 'NOUN'), ('wealthy', 'ADJ'))],
#  [('and', 'CONJ'), (('well-connected', 'NOUN'), ('well-connected', 'ADJ'))],
#  [('obtained', 'VERB'), (('financing', 'VERB'), ('financing', 'NOUN'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('to', 'PRT'), (('Moon', 'VERB'), ('Moon', 'NOUN'))],
#  [('Moon', 'NOUN'), (('Landrieu', 'X'), ('Landrieu', 'NOUN'))],
#  [('build', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('cavernous', 'VERB'), ('cavernous', 'ADJ'))],
#  [(',', '.'), (('money-losing', 'NOUN'), ('money-losing', 'ADJ'))],
#  [('*T*-2', 'X'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('the', 'DET'), (('U.S.', 'NOUN'), ('U.S.', 'ADJ'))],
#  [('at', 'ADP'), (('143.93', 'DET'), ('143.93', 'NUM'))],
#  [('Tokyo', 'NOUN'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('of', 'ADP'), (('143.08', 'DET'), ('143.08', 'NUM'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('or', 'CONJ'), (('burn', 'NOUN'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', 'NOUN'), ('cleaner-burning', 'ADJ'))],
#  [('of', 'ADP'), (('858,000', 'DET'), ('858,000', 'NUM'))],
#  [('market', 'NOUN'), (('overvalued', 'NOUN'), ('overvalued', 'VERB'))],
#  [('II', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('$', '.'), (('306', 'NOUN'), ('306', 'NUM'))],
#  [('an', 'DET'), (('unrestricted', 'NOUN'), ('unrestricted', 'ADJ'))],
#  [('wage', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('firm', 'NOUN'), ('firm', 'ADJ'))],
#  [('steady', 'ADJ'), (('opening', 'VERB'), ('opening', 'NOUN'))],
#  [('finished', 'VERB'), (('less', 'ADV'), ('less', 'ADJ'))],
#  [('point', 'NOUN'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('moderate', 'ADJ'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('its', 'PRON'), (('glory', 'VERB'), ('glory', 'NOUN'))],
#  [('had', 'VERB'), (('faded', 'X'), ('faded', 'VERB'))],
#  [('the', 'DET'), (('yellow', 'NOUN'), ('yellow', 'ADJ'))],
#  [('The', 'DET'), (('record', 'NOUN'), ('record', 'ADJ'))],
#  [('$', '.'), (('550,000', 'NOUN'), ('550,000', 'NUM'))],
#  [('.', '.'), (('Four', 'NOUN'), ('Four', 'NUM'))],
#  [('by', 'ADP'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('a', 'DET'), (('27-year', 'NOUN'), ('27-year', 'ADJ'))],
#  [(',', '.'), (('Southeast', 'NOUN'), ('Southeast', 'ADJ'))],
#  [('By', 'ADP'), (('1997', 'DET'), ('1997', 'NUM'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('of', 'ADP'), (('cancer-causing', 'DET'), ('cancer-causing', 'ADJ'))],
#  [('be', 'VERB'), (('outlawed', 'X'), ('outlawed', 'VERB'))],
#  [('departure', 'NOUN'), (('stemmed', 'NOUN'), ('stemmed', 'VERB'))],
#  [("'s", 'PRT'), (('post', 'VERB'), ('post', 'NOUN'))],
#  [('a', 'DET'), (('little', 'ADJ'), ('little', 'ADV'))],
#  [('little', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('precisely', 'ADV'), (('what', 'PRON'), ('what', 'DET'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-117', 'DET'), ('*T*-117', 'X'))],
#  [('to', 'PRT'), (('uptick', 'NOUN'), ('uptick', 'VERB'))],
#  [(',', '.'), (('head', 'NOUN'), ('head', 'ADJ'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('in', 'ADP'), (('jeopardy', 'DET'), ('jeopardy', 'NOUN'))],
#  [('$', '.'), (('14.75', 'NOUN'), ('14.75', 'NUM'))],
#  [(',', '.'), (('63-year-old', 'NOUN'), ('63-year-old', 'ADJ'))],
#  [('of', 'ADP'), (('English', 'ADJ'), ('English', 'NOUN'))],
#  [('named', 'VERB'), (('Earle', 'X'), ('Earle', 'NOUN'))],
#  [('Earle', 'NOUN'), (('Palmer', 'VERB'), ('Palmer', 'NOUN'))],
#  [('*U*', 'X'), (('account', 'VERB'), ('account', 'NOUN'))],
#  [('Once', 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [(',', '.'), (('what', 'PRON'), ('what', 'DET'))],
#  [('of', 'ADP'), (('escape', 'DET'), ('escape', 'NOUN'))],
#  [('*T*-1', 'X'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('than', 'ADP'), (('drink', 'VERB'), ('drink', 'NOUN'))],
#  [('push', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('from', 'ADP'), (('malnutrition', 'DET'), ('malnutrition', 'NOUN'))],
#  [(',', '.'), (('cardiovascular', 'NOUN'), ('cardiovascular', 'ADJ'))],
#  [(',', '.'), (('infectious', 'NOUN'), ('infectious', 'ADJ'))],
#  [('of', 'ADP'), (('assaults', 'DET'), ('assaults', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-91', 'VERB'), ('*T*-91', 'X'))],
#  [('at', 'ADP'), (('879', 'DET'), ('879', 'NUM'))],
#  [('$', '.'), (('13.90', 'NOUN'), ('13.90', 'NUM'))],
#  [('no', 'DET'), (('guarantee', 'VERB'), ('guarantee', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'NOUN'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('nearly', 'ADV'), (('half', 'DET'), ('half', 'NOUN'))],
#  [('consumers', 'NOUN'), (('espouse', 'NOUN'), ('espouse', 'VERB'))],
#  [('with', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('about', 'ADV'), (('one-third', 'NOUN'), ('one-third', 'ADJ'))],
#  [('its', 'PRON'), (('finance', 'VERB'), ('finance', 'NOUN'))],
#  [('of', 'ADP'), (('deteriorating', 'DET'), ('deteriorating', 'VERB'))],
#  [('a', 'DET'), (('59-year-old', 'NOUN'), ('59-year-old', 'ADJ'))],
#  [('see', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('point', 'VERB'), ('point', 'NOUN'))],
#  [('the', 'DET'), (('audit', 'VERB'), ('audit', 'NOUN'))],
#  [("'s", 'PRT'), (('stand', 'VERB'), ('stand', 'NOUN'))],
#  [('and', 'CONJ'), (('underline', 'NOUN'), ('underline', 'VERB'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'NOUN'), ('126,000', 'NUM'))],
#  [('are', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('a', 'DET'), (('following', 'VERB'), ('following', 'NOUN'))],
#  [('two', 'NUM'), (('round-trip', 'NOUN'), ('round-trip', 'ADJ'))],
#  [('on', 'ADP'), (('Trans', 'DET'), ('Trans', 'NOUN'))],
#  [('prices', 'NOUN'), (('soaring', 'NOUN'), ('soaring', 'VERB'))],
#  [('the', 'DET'), (('reclaimed', 'NOUN'), ('reclaimed', 'VERB'))],
#  [("'s", 'PRT'), (('240-page', 'VERB'), ('240-page', 'ADJ'))],
#  [('240-page', 'ADJ'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('$', '.'), (('221.4', 'NOUN'), ('221.4', 'NUM'))],
#  [('.', '.'), (('Next', 'NOUN'), ('Next', 'ADJ'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('be', 'VERB'), (('capped', 'ADJ'), ('capped', 'VERB'))],
#  [('by', 'ADP'), (('Philippine', 'DET'), ('Philippine', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NOUN'))],
#  [('until', 'ADP'), (('midyear', 'DET'), ('midyear', 'NOUN'))],
#  [(',', '.'), (('nonresidential', 'NOUN'), ('nonresidential', 'ADJ'))],
#  [('was', 'VERB'), (('off', 'PRT'), ('off', 'ADJ'))],
#  [('$', '.'), (('99.1', 'NOUN'), ('99.1', 'NUM'))],
#  [('market', 'NOUN'), (('awaits', 'NOUN'), ('awaits', 'VERB'))],
#  [('will', 'VERB'), (('point', 'NOUN'), ('point', 'VERB'))],
#  [('earnings', 'NOUN'), (('sagged', 'NOUN'), ('sagged', 'VERB'))],
#  [('lower', 'ADJ'), (('B-1B', 'ADJ'), ('B-1B', 'NOUN'))],
#  [('rolled', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('first', 'ADJ'), (('half', 'NOUN'), ('half', 'DET'))],
#  [('to', 'PRT'), (('88.32', 'VERB'), ('88.32', 'NUM'))],
#  [('$', '.'), (('618.1', 'NOUN'), ('618.1', 'NUM'))],
#  [('from', 'ADP'), (('77.6', 'DET'), ('77.6', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('$', '.'), (('12.52', 'NOUN'), ('12.52', 'NUM'))],
#  [('$', '.'), (('11.95', 'NOUN'), ('11.95', 'NUM'))],
#  [('meetings', 'NOUN'), (('next', 'ADP'), ('next', 'ADJ'))],
#  [('and', 'CONJ'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('waters', 'NOUN'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('off', 'ADP'), (('Malta', 'VERB'), ('Malta', 'NOUN'))],
#  [('so', 'ADV'), (('broadly', 'VERB'), ('broadly', 'ADV'))],
#  [('broadly', 'ADV'), (('construed', 'X'), ('construed', 'VERB'))],
#  [('would', 'VERB'), (('emasculate', 'X'), ('emasculate', 'VERB'))],
#  [('and', 'CONJ'), (('swallow', 'NOUN'), ('swallow', 'VERB'))],
#  [('``', '.'), (('contrary', 'NOUN'), ('contrary', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'NUM'))]]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %% [markdown]
# #### Accuracy comparison
# 1. The accuracy of vanilla Viterbi based POS tagger on validation set is 90.3%
# 2. The accuracy of modified viterbi using rule based technique on validation set is 95%
# 3. The accuracy of modified viterbi using probability technique on validation set is 93.3%

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %% [markdown]
# #### Observations
# 1. The unknown words 'outlawing', 'safeguarding' and 'Indexing' are correctly tagged as verbs by modified veterbi algorithms
# 2. The unknown words like 'broadened', 'shopped' and 'delayed' are correctly tagged as verbs by modified veterbi algorithms
# 3. The unknown words like 'argues' and 'illustrates' are correctly tagged as verbs by modified veterbi algorithms
# 4. The unknown words like 'third-largest' and 'finest' are correctly tagged as adjectives by modified veterbi with rule based algorithms
# 5. The unknown words like 'broadly' and 'faultlessly' are correctly tagged as adverbs
# 6. The decimal numbers like '89.7' and '141.9' are correctly tagged as 'NUM'

# %% [markdown]
# #### Testing on test set

# %%
#### Evaluation on test set

sentence_test = """Android is a mobile operating system developed by Google.
Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.
Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose.
Twitter is an online news and social networking service on which users post and interact with messages known as tweets.
Before entering politics, Donald Trump was a domineering businessman and a television personality.
The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.
This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.
Show me the cheapest round trips from Dallas to Atlanta
I would like to see flights from Denver to Philadelphia.
Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.
NASA invited social media users to experience the launch of ICESAT-2 Satellite."""

words = word_tokenize(sentence_test)

# %%
# Evaluation on test set using vanilla viterbi
tagged_seq = Viterbi(words)
print(tagged_seq)
# Out:
# [('Android', 'NUM'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NUM'), ('.', '.'), ('Android', 'NUM'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NUM'), ('worldwide', 'NUM'), ('on', 'ADP'), ('smartphones', 'NUM'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.'), ('Google', 'NUM'), ('and', 'CONJ'), ('Twitter', 'NUM'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NUM'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NUM'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NUM'), ("'s", 'PRT'), ('firehose', 'NUM'), ('.', '.'), ('Twitter', 'NUM'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NUM'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NUM'), ('with', 'ADP'), ('messages', 'NUM'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'NUM'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NUM'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NUM'), ('.', '.'), ('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NUM'), ('World', 'NOUN'), ('Cup', 'NUM'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NUM'), ('FIFA', 'NUM'), ('World', 'NOUN'), ('Cup', 'NUM'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NUM'), ('contested', 'NUM'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NUM'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NUM'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NUM'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NUM'), ('invited', 'NUM'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NUM'), ('Satellite', 'NUM'), ('.', '.')]

# %%
# Evaluation on test set using modified viterbi using rule based technique
tagged_seq = Viterbi_backedoff_with_rule_based(words)
print(tagged_seq)
# Out:
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'VERB'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'ADJ'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NUM'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'ADJ'), ("'s", 'PRT'), ('firehose', 'NOUN'), ('.', '.'), ('Twitter', 'ADJ'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'VERB'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'NOUN'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'VERB'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'VERB'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'NOUN'), ('.', '.')]

# %%
# Evaluation on test set using modified viterbi using probability technique
tagged_seq = Viterbi_backedoff_with_probability_technique(words)
print(tagged_seq)
# Out:
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'DET'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'DET'), ('since', 'ADP'), ('2011', 'DET'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'DET'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'DET'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'X'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'VERB'), ("'s", 'PRT'), ('firehose', 'VERB'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'DET'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'DET'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NOUN'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'NOUN'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NOUN'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'NOUN'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'DET'), ('Satellite', 'NOUN'), ('.', '.')]
